# %% [markdown]
# <a href="https://colab.research.google.com/github/Goforthekill/Gemini-Ratelimit-Increaser/blob/main/DeFooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title DeFooocus
#@markdown **Launch the interface DeFocus (Fooocus fork)** | You need to connect with T4/A100/V100
#@markdown ****
#@markdown *Attention!* When working in the interface with the FaceSwap and CPDS controlnet, crashes are possible; it is also recommended to work in *Extreme speed* mode for additional stability. When working with the ImagePrompt and PyraCanny controls, 85% of the work will be stable.
#@markdown ****

print("[DeFooocus] Preparing ...")

theme = "dark" #@param ["dark", "light"]
preset = "default" #@param ["default", "realistic", "anime", "lcm", "sai", "turbo", "lighting", "hypersd", "playground_v2.5", "dpo", "spo", "sd1.5"]
advanced_args = "--share --attention-split --always-high-vram --disable-offload-from-vram --all-in-fp16" #@param {type: "string"}

if preset != "default":
  args = f"{advanced_args} --theme {theme} --preset {preset}"
else:
  args = f"{advanced_args} --theme {theme}"

# %cd /content

# FIX 1: Ensure a clean state by removing the directory if it exists.
# This prevents the "destination path 'DeFooocus' already exists" error on subsequent runs.
# !rm -rf /content/DeFooocus

# !git clone https://github.com/ehristoforu/DeFooocus.git
# %cd /content/DeFooocus

# FIX 2: Use a more robust pip install command.
# --no-cache-dir: Prevents using a bad cached version of a package.
# --force-reinstall: Uninstalls existing packages (like Colab's default gradio)
# before installing the specific versions from the file. This is the key
# to solving the 'IOComponent' ImportError and other version mismatches.
print("[DeFooocus] Installing Dependencies...")
# !pip install --no-cache-dir --force-reinstall -r requirements_versions.txt

print("[DeFooocus] Starting ...")
# !python entry_with_update.py $args
# Out:
# [DeFooocus] Preparing ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   error: subprocess-exited-with-error
#
#   × Building wheel for pygit2 (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pygit2
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pygit2)
# /content
# fatal: destination path 'DeFooocus' already exists and is not an empty directory.
# /content/DeFooocus
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
# ...
